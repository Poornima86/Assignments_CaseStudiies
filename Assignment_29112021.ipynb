# %% [markdown]
# # Case Study on Measures of Central Tendency and Dispersion - 29/11/2021

# %% [markdown]
#     1. Read the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data_set=pd.read_excel(r"C:\python learning\StudentsPerformance.xls")
data_set.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
#     2 . Find out how many males and females participated in the test.

# %%
print("Gender Count")
count=data_set['gender'].value_counts(ascending=True)
print(count)
# Out:
# Gender Count
# male      482
# female    518
# Name: gender, dtype: int64

# %% [markdown]
#     Insight : Inorder to get how many males and females participated in test we can use value_counts() of that column

# %% [markdown]
#     3 . What do you think about the students' parental level of education?

# %%
print("Parental level of Education")
parents = data_set["parental level of education"].value_counts(ascending=True)
parents
# Out:
# Parental level of Education
# master's degree        59
# bachelor's degree     118
# some high school      179
# high school           196
# associate's degree    222
# some college          226
# Name: parental level of education, dtype: int64

# %% [markdown]
#      Below code shows the count of parent's level of education.Its seen by using value_counts().

# %% [markdown]
#      A bar chart is plotted with this information.

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=70)
plt.title("Parental level of Education")
sns.barplot(parents.index, parents);
# Out:
# C:\Users\Poornima\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#         It appears that parents studied in some college is highest. Parents with associate's degree is close to this but master's degree is too low.

# %% [markdown]
#     4. Who scores the most on average for math, reading and writing based on
#       ● Gender
#       ● Test preparation course

# %% [markdown]
# # Gender wise

# %%
data_set[['gender',
      'math score',
       'reading score','writing score']].groupby(['gender']).agg('mean')
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %% [markdown]
#      Insight : Average of math score,reading score,writing score,reading score of genders.From this data we can find in math score male has average score high,in reading score female has high score,Writing score female has high score.

# %% [markdown]
# # Test prepartion course

# %%
data_set[['test preparation course',
      'math score',
       'reading score','writing score']].groupby(['test preparation course']).agg('mean')
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
#       Insight : Average of math score,reading score,writing score,reading score of test prepartion course.From this data we can find in completed has math score,reading score,writing score high

# %% [markdown]
#     5. What do you think about the scoring variation for math, reading and writing
#            based on
#            ● Gender
#            ● Test preparation course

# %%
data_set[['test preparation course','gender',
      'math score',
      'writing score',
      'reading score']].groupby(['test preparation course','gender']).agg('mean')
# Out:
#                                 math score  writing score  reading score
# test preparation course gender
# completed               female   67.108696      78.793478      77.375000
#                         male     72.988506      70.339080      70.793103
# none                    female   61.320359      68.982036      69.955090
#                         male     66.467532      59.551948      62.581169

# %% [markdown]
#      From this data,its clear that female gender with test prepartion course has the highest score

# %% [markdown]
#     5. The management needs your help to give bonus points to the top 25% of students based on their maths score, so how
#     will you help the management to achieve this.

# %%
print("Top 25 Students")
dataset2=data_set.sort_values(by="math score",ascending=False)
dataset2.head(25)
# Out:
# Top 25 Students
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 995    male        group E                some college      standard
# 513  female        group E           bachelor's degree      standard
# 514  female        group E                 high school      standard
# 994    male        group C          associate's degree      standard
# 993    male        group C                some college      standard
# ...

# %% [markdown]
#       By sorting on the basis of math score descending we can get the descending order dataframe.Inorder to display the top 25 students just call dattaframe(No of data to display)
