# %% [markdown]
# # Case study on Unsupervised Learning

# %% [markdown]
# ### LOAD DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.cluster import KMeans

# %%
Wine_data=pd.read_csv(r'C:\Users\Poornima\Downloads\Wine.csv')
Wine_data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %% [raw]
# DataFrame contains 178 rows X 13 columns

# %%
Wine_data.shape
# Out:
# (178, 13)

# %%
Wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
Wine_data.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %% [raw]
# Dataset doesn't contain any null values.There are no missing values.

# %%
Wine_data.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
plt.rcParams['figure.figsize'] = (15.0, 15.0)
plt.title("Correlation Plot")
sns.heatmap(Wine_data.corr())
# Out:
# <AxesSubplot:title={'center':'Correlation Plot'}>

# %% [raw]
# Looks like Total_Phenlos and Flavanoids are correlated.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Wine_data_copy = Wine_data.copy()
Wine_data_copy = pd.DataFrame(scaler.fit_transform(Wine_data),index=Wine_data.index,columns=Wine_data.columns)
Wine_data_copy
# Out:
#       Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    1.518613   -0.562250  0.232053     -1.169593   1.913905       0.808997
# 1    0.246290   -0.499413 -0.827996     -2.490847   0.018145       0.568648
# 2    0.196879    0.021231  1.109334     -0.268738   0.088358       0.808997
# 3    1.691550   -0.346811  0.487926     -0.809251   0.930918       2.491446
# 4    0.295700    0.227694  1.840403      0.451946   1.281985       0.808997
# ..        ...         ...       ...           ...        ...            ...
# 173  0.876275    2.974543  0.305159      0.301803  -0.332922      -0.985614
# 174  0.493343    1.412609  0.414820      1.052516   0.158572      -0.793334
# 175  0.332758    1.744744 -0.389355      0.151661   1.422412      -1.129824
# 176  0.209232    0.227694  0.012732      0.151661   1.422412      -1.033684
# 177  1.395086    1.583165  1.365208      1.502943  -0.262708      -0.392751
#
# ...

# %% [raw]
# 178 rows × 13 columns

# %% [markdown]
# ### K-Means Clustering Implementation

# %%
X1 = Wine_data_copy.iloc[: , :].values
inertia = []
for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state = 823, algorithm='elkan') )
    algorithm.fit(X1)
    inertia.append(algorithm.inertia_)
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('WCSS')
plt.title('Elbow Method Diagram')
plt.show()
# Out:
# C:\Users\Poornima\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:827: RuntimeWarning: algorithm='elkan' doesn't make sense for a single cluster. Using 'full' instead.
#   warnings.warn("algorithm='elkan' doesn't make sense for a single "
# C:\Users\Poornima\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [raw]
# The best number of clusters is 3 because the Within-Cluster-Sum of Squared Errors (WCSS) starts to diminish at k = 3.

# %%
Wine_data=pd.read_csv(r'C:\Users\Poornima\Downloads\Wine.csv')
Wine_data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
sns.scatterplot(x='Flavanoids', y='Total_Phenols', data=Wine_data);

# %%
from scipy.cluster.hierarchy import linkage,dendrogram , fcluster

# %%
samples=Wine_data[['Total_Phenols','OD280']]
from sklearn.decomposition import PCA
model=PCA()
model.fit(samples)
transformed=model.transform(samples)
print(model.components_)
transformed[:10]
# Out:
# [[-0.64116665 -0.76740167]
#  [-0.76740167  0.64116665]]
# array([[-1.32771994,  0.45139607],
#        [-0.83249607,  0.23309966],
#        [-0.75216868, -0.02947892],
#        [-1.64026613, -0.65572401],
#        [-0.56799228, -0.18335891],
#        [-0.80794847, -0.59533103],
#        [-0.87445337,  0.46361991],
#        [-0.93857004,  0.38687974],
#        [-0.50660014, -0.23465224],
#        [-1.15919131,  0.07603211]])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_copy = df.copy()
df_copy = pd.DataFrame(scaler.fit_transform(df), 
                                      index=df.index,
                                      columns=df.columns)
df_copy
# Out:
#        labels     class
# 0   -0.045889  1.913905
# 1   -0.045889  0.018145
# 2   -0.045889  0.088358
# 3   -0.045889  0.930918
# 4   -1.212782  1.281985
# ..        ...       ...
# 173 -1.212782 -0.332922
# 174 -1.212782  0.158572
# 175 -1.212782  1.422412
# 176 -1.212782  1.422412
# 177  1.121004 -0.262708
#
# [178 rows x 2 columns]
